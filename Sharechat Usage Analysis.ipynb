# %%
import pandas as pd

# %%
sc = pd.read_excel('/Users/5nip3r/Downloads/SharechatUsage.xlsx')

# %%
sc.head()
# Out:
#    Sorting General                  Account Name Account ID  Subscription ID  \
# 0                1  Mohalla Tech Private Limited   SM808555          1200754
# 1                2  Mohalla Tech Private Limited   SM808555          1639936
# 2                3  Mohalla Tech Private Limited   SM808555          1041818
# 3                4  Mohalla Tech Private Limited   SM939842          1180061
# 4                5  Mohalla Tech Private Limited   SM939842          1449230
#
#   Cloud Provider     Cloud Region     DB ID Db Delete  \
# 0            GCP  asia-southeast1  10102450       NaN
# 1            GCP      asia-south1  10773863       NaN
# 2            GCP      asia-south1   9583407       NaN
# 3            GCP  asia-southeast1  11408647       NaN
# 4            GCP  asia-southeast1  10510346       NaN
#
#                       DB Name Highest Memory Limit (GB)  ...  \
# 0      view-service-events-v2                     2,050  ...
# ...
